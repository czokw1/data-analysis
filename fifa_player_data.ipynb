# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/fifa_data.csv')
data.drop(columns=['Unnamed: 0', 'ID', 'Photo', 'Flag', 'Club Logo'], axis='columns', inplace=True)
#pd.options.display.max_columns = 90 
data.sample(5)
# Out:
#                  Name  Age Nationality  Overall  Potential  \
# 6670   Márcio Velinha   30      Brazil       68         68
# 12917        Tang Shi   23    China PR       63         70
# 6878    Jiang Zhipeng   29    China PR       68         68
# 917        C. Grenier   27      France       77         78
# 15646      J. Falkmar   26      Sweden       59         60
#
#                                  Club  Value  Wage  Special Preferred Foot  \
# 6670                      Chapecoense  €575K   €5K     1121          Right
# 12917  Guangzhou Evergrande Taobao FC  €525K   €3K     1642           Left
# 6878           Hebei China Fortune FC  €675K   €6K     1868           Left
# 917                  Stade Rennais FC   €10M  €32K     2031          Right
# 15646               IF Brommapojkarna  €150K   €1K     1493          Right
#
#        ...  Composure  Marking  StandingTackle SlidingTackle GKDiving  \
# 6670   ...       58.0     13.0             8.0          12.0     69.0
# ...

# %%
data.shape
# Out:
# (18207, 84)

# %% [markdown]
# ## GROUPING & PLOTTING

# %%
team = data.groupby('Club')
len(team)
# Out:
# 651

# %%
team.size().nlargest(5)
# Out:
# Club
# AS Monaco            33
# Arsenal              33
# Atlético Madrid      33
# Borussia Dortmund    33
# Burnley              33
# dtype: int64

# %%
arsenal = team.get_group('Arsenal')

arsenal.head()
# Out:
#               Name  Age Nationality  Overall  Potential     Club   Value  \
# 33   P. Aubameyang   29       Gabon       88         88  Arsenal    €59M
# 74         M. Özil   29     Germany       86         86  Arsenal  €43.5M
# 87    A. Lacazette   27      France       85         86  Arsenal    €45M
# 131        B. Leno   26     Germany       84         87  Arsenal    €27M
# 146       Sokratis   30      Greece       84         84  Arsenal    €23M
#
#       Wage  Special Preferred Foot  ...  Composure  Marking  StandingTackle  \
# 33   €265K     2069          Right  ...       86.0     27.0            25.0
# 74   €190K     1911           Left  ...       82.0     24.0            16.0
# 87   €180K     2060          Right  ...       85.0     29.0            42.0
# 131  €115K     1278          Right  ...       66.0     27.0            15.0
# 146  €140K     1797          Right  ...       82.0     85.0            87.0
#
# ...

# %%
arsenal['Wage'] = arsenal['Wage'].str.replace('€','').str.replace('K','')
# Out:
# C:\MyPrograms\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
